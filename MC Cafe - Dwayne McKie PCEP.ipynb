# %%
# Welcome user to the MC Cafe
print(" ")
print(" ")
print("Welcome to MC Cafe!")


menu_view = "y"

print(" ")
print(" ")


item_order = input("Do you want to see the menu?:  y/n  ")
print(" ")
print(" ")




if item_order.lower() == 'y' :
    print(f"\t\tMC Cafe Menu")
    print(" ")
    print(f"\tCoffee")
    print(f"\t\tEspresso - $1.50")
    print(f"\t\tAmericano - $2.00")
    print(f"\t\tCaffe latte - $2.25")
    print(f"\t\tMocha - $2.25")
    print(f"\t\tCappucino - $2.50")
    print(f"\t\tMacchiato - $2.50")
    print(" ")
    print(f"\tTea")
    print(f"\t\tWhite tea - $1.50")
    print(f"\t\tGreen tea - $2.00")
    print(f"\t\tOolong tea - $2.25")
    print(f"\t\tBlack tea - $2.25")
    print(f"\t\tEarl Grey - $2.50")
    print(f"\t\tMatcha - $2.50")
    print(" ")
    print(f"\tPastries")
    print(f"\t\tCroissant - $5.50")
    print(f"\t\tCinnamon roll - $4.50")
    print(f"\t\tBanana bread - $4.25")
    print(f"\t\tPumpkin bread - $3.75")
    print(f"\t\tSticky bun - $4.25")
    print(f"\t\tApple turnover - $3.75")
    print(" ")





item_group = " "

item_amount = 0

item_price = 0.0

item_total = 0.0

order_subtotal = 0.0

order_tax = 0.0

order_grand_total = 0.0

menu_order = []


answer = 'y'

answer = input("Do you want to place an order:  y/n  ")

if answer.lower() == 'n' :
    menu_order.append("nothing")


while answer.lower() != 'n' :
    print(" ")
    print(" ")


    print(" ")
    item_order = input("What food or drink do you want:    ")

    
    print(" ")
    item_amount = int(input("Quantity:    "))
    
    print(" ")


    if item_order.lower() == "espresso" :
        item_price = 1.50
        item_group = "Coffee"
        item_order = "Espresso"
    elif item_order.lower() == "americano" :
        item_price = 2.00
        item_group = "Coffee"
        item_order = "Americano"
    elif item_order.lower() == "caffe latte" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Caffe latte"
    elif item_order.lower() == "mocha" :
        item_price = 2.25
        item_group = "Coffee"
        item_order = "Mocha"
    elif item_order.lower() == "cappucino" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Cappucino"
    elif item_order.lower() == "macchiato" :
        item_price = 2.50
        item_group = "Coffee"
        item_order = "Macchiato"
    elif item_order.lower() == "white tea" :
        item_price = 1.50
        item_group = "Tea"
        item_order = "White tea"
    elif item_order.lower() == "green tea" :
        item_price = 2.00
        item_group = "Tea"
        item_order = "Green tea"
    elif item_order.lower() == "oolong tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Oolong tea"
    elif item_order.lower() == "black tea" :
        item_price = 2.25
        item_group = "Tea"
        item_order = "Black tea"
    elif item_order.lower() == "earl grey" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Earl Grey"
    elif item_order.lower() == "matcha" :
        item_price = 2.50
        item_group = "Tea"
        item_order = "Matcha"
    elif item_order.lower() == "croissant" :
        item_price = 5.50
        item_group = "Pastry"
        item_order = "Croissant"
    elif item_order.lower() == "cinnamon roll" :
        item_price = 4.50
        item_group = "Pastry"
        item_order = "Cinnamon roll"
    elif item_order.lower() == "banana bread" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Banana bread"
    elif item_order.lower() == "pumpkin bread" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Pumpkin bread"
    elif item_order.lower() == "sticky bun" :
        item_price = 4.25
        item_group = "Pastry"
        item_order = "Sticky bun"
    elif item_order.lower() == "apple turnover" :
        item_price = 3.75
        item_group = "Pastry"
        item_order = "Apple turnover"
    else :
        print("The item entered is not on the menu...")
        continue
        

    menu_order.append(item_group)
    menu_order.append(item_order)
    menu_order.append(item_amount)
    menu_order.append(item_price)


    item_total = item_amount * item_price

    menu_order.append(item_total)

    order_subtotal = order_subtotal + item_total

    print(" ")
    print(" ")
    answer = input("Do you want to add another item to your order? y/n:    ")


order_length = 0

order_length = len(menu_order)//5    
    
order_tax = order_subtotal * 0.06

order_grand_total = order_subtotal + order_tax

print(" ")
print(" ")


if menu_order[0] != "nothing" :
    for i in range(0, order_length) :
        print(f"Group:\t\t{menu_order[i*5]}")
        print(f"Item:\t\t{menu_order[i*5+1]}")
        print(f"Quantity:\t{menu_order[i*5+2]}")
        print(f"Price:\t\t$ {menu_order[i*5+3]:.2f}")
        print(f"Item Total:\t$ {menu_order[i*5+4]:.2f}")
        print(" ")

    print(" ")
    print(" ")

    print(f"Subtotal:\t$ {order_subtotal:.2f}")

    print(f"Tax:\t\t$ {order_tax:.2f}")

    print(f"Total:\t\t$ {order_grand_total:.2f}")


print(" ")
print(" ")
print("Thank you for visiting MC Cafe!")
# Out:
#
#
# Welcome to MC Cafe!
#
#
# Do you want to see the menu?:  y/n  y
#
#
# 		MC Cafe Menu
#
# 	Coffee
# 		Espresso - $1.50
# 		Americano - $2.00
# 		Caffe latte - $2.25
# 		Mocha - $2.25
# 		Cappucino - $2.50
# 		Macchiato - $2.50
#
# 	Tea
# 		White tea - $1.50
# 		Green tea - $2.00
# 		Oolong tea - $2.25
# 		Black tea - $2.25
# 		Earl Grey - $2.50
# 		Matcha - $2.50
#
# 	Pastries
# 		Croissant - $5.50
# 		Cinnamon roll - $4.50
# 		Banana bread - $4.25
# 		Pumpkin bread - $3.75
# 		Sticky bun - $4.25
# 		Apple turnover - $3.75
#
# Do you want to place an order:  y/n  y
#
#
#
# What food or drink do you want:    Croissant
#
# Quantity:    2
#
#
#
# Do you want to add another item to your order? y/n:    y
#
#
#
# What food or drink do you want:    Espresso
#
# Quantity:    2
#
#
#
# Do you want to add another item to your order? y/n:    y
#
#
#
# What food or drink do you want:    Earl Grey
#
# Quantity:    5
#
#
#
# Do you want to add another item to your order? y/n:    n
#
#
# ...
